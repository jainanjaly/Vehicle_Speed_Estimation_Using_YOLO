# %% [markdown]
# Import necessary package

# %%
# pip install Ultralytics
from Ultralytics import YOLO

# %% [markdown]
# # Training

# %% [markdown]
# Download the data.yaml file and run the following command

# %%
#To remove the extra column in the lables.txt file
! for i in $(ls MVI_*/img1/*); do sed -i 's/\s*[^ ]*//2' $i; done

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=10 imgsz=224
# Results will be saved into a folder named 'runs'

# %% [markdown]
# Sample training output screenshot

# %% [markdown]
# ![Screenshot from 2023-11-23 22-02-06.png](<attachment:Screenshot from 2023-11-23 22-02-06.png>)

# %% [markdown]
# # Validation

# %% [markdown]
# Validate the new model on images it has not seen before

# %%
# !yolo task=detect mode=val model="runs/detect/train11/weights/best.pt" data=data.yaml

# %% [markdown]
# # Testing

# %% [markdown]
# Testing the model on all the avalaible test data set

# %%
! pwd
# Out:
# /home/anjaly/Desktop/speed_source_code/model_training

# %%
! for file in $(ls ../data_preparation/data/MOT/DETRAC/test/DETRAC-test-data/Insight-MVT_Annotation_Test/) ; do yolo task=detect mode=predict model="runs/detect/train11/weights/best.pt" source="../data_preparation/data/MOT/DETRAC/test/DETRAC-test-data/Insight-MVT_Annotation_Test/${file}" ; done
